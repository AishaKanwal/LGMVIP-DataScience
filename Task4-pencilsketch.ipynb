# %% [markdown]
# <a href="https://colab.research.google.com/github/AishaKanwal/LGMVIP-DataScience/blob/main/Task4-pencilsketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LetsGrowMore - VirtualInternshipProgram - LGMVIP | DataScienceInternship**
# > **Task 4 - Image to Pencil Sketch with Python**
#
# > **Aisha Kanwal | Internee**

# %% [markdown]
# ## Install opencv-python library for working on an image.

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Load library from google colab

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Load RGB image from Google Drive

# %%
from google.colab import drive
# drive.mount('/content/drive')
image_path = '/content/drive/MyDrive/ColabNotebooks/doll.jpeg'
img = cv2.imread(image_path)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F89D6AC42E0>

# %% [markdown]
# # Converting RGB to grayscale image

# %%
# Convert the image to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F89D6AE14B0>

# %% [markdown]
# # Inverting grayscale

# %%
# Invert the grayscale image
inverted_gray_image = 255 - gray_image
cv2_imshow(inverted_gray_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F89D6AE2BF0>

# %% [markdown]
# # Applying Guassian Function

# %%
# Apply Gaussian Blur to the inverted image
blurred_image = cv2.GaussianBlur(inverted_gray_image, (21, 21), 0)
cv2_imshow(blurred_image)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F89C3A47CD0>

# %% [markdown]
# # Blending grayscale image

# %%
# Blend the grayscale image with the blurred image using the "color dodge" blend mode
def dodgeV2(image, mask):
  return cv2.divide(image, 255 - mask, scale=256)

pencil_sketch = dodgeV2(gray_image, blurred_image)

cv2_imshow(pencil_sketch)
# Out:
# <PIL.Image.Image image mode=L size=600x400 at 0x7F89C3A44FD0>

# %% [markdown]
# # Original Image vs Pencil Sketch

# %%
# Display the original image and the pencil sketch
print("RGB image")
cv2_imshow(img)
print("\n")
print("Pencil Sketch") 
cv2_imshow(pencil_sketch)
# Out:
# RGB image
# <PIL.Image.Image image mode=RGB size=600x400 at 0x7F89C3A475E0>
# Pencil Sketch
# <PIL.Image.Image image mode=L size=600x400 at 0x7F89C3A45240>

# %% [markdown]
# # Task 4 - Image to Pencil Sketch with Python
# **Done by Aisha Kanwal**
